# %% [markdown]
# <a href="https://colab.research.google.com/github/raju1207/Iris-Flower-Dataset/blob/main/Iris_Flower_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
Flower_Dataset = pd.read_csv('IRIS.csv')

# %%
Flower_Dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
 # Q-1: What is the average petal length for each species?

# %%
Flower_Dataset.groupby('species')['petal_length'].mean()
# Out:
# species
# Iris-setosa        1.464
# Iris-versicolor    4.260
# Iris-virginica     5.552
# Name: petal_length, dtype: float64

# %%
 # Q-2: How many samples are there for each species?

# %%
Flower_Dataset['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
 # Q-3: What is the maximum sepal width for each species?

# %%
Flower_Dataset.groupby('species')['sepal_width'].max()
# Out:
# species
# Iris-setosa        4.4
# Iris-versicolor    3.4
# Iris-virginica     3.8
# Name: sepal_width, dtype: float64

# %%
 # Q-4: How are sepal length and petal length correlated?

# %%
Flower_Dataset[['sepal_length', 'petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.871754
# petal_length      0.871754      1.000000

# %%
 # Q-5: Which samples have a petal width greater than 2 cm?

# %%
Flower_Dataset[Flower_Dataset['petal_width'] > 2]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 112           6.8          3.0           5.5          2.1  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 115           6.4          3.2           5.3          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 124           6.7          3.3           5.7          2.1  Iris-virginica
# ...

# %%
 # Q-6: What is the proportion of each species where petal length is above the median petal length of the dataset?

# %%
Flower_Dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
median_petal_length = Flower_Dataset['petal_length'].median()
data_above_median = Flower_Dataset[Flower_Dataset['petal_length'] > median_petal_length]
data_above_median['species'].value_counts(normalize=True)
# Out:
# species
# Iris-virginica     0.666667
# Iris-versicolor    0.333333
# Name: proportion, dtype: float64

# %%
 # Q-7: Are there outliers in sepal width for each species based on the interquartile range (IQR)?

# %%
def find_outliers(group):
    Q1 = group['sepal_width'].quantile(0.25)
    Q3 = group['sepal_width'].quantile(0.75)
    IQR = Q3 - Q1
    return group[(group['sepal_width'] < Q1 - 1.5 * IQR) | (group['sepal_width'] > Q3 + 1.5 * IQR)]

outliers = Flower_Dataset.groupby('species').apply(find_outliers)
# Out:
# <ipython-input-14-1d7a1e7161f2>:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   outliers = Flower_Dataset.groupby('species').apply(find_outliers)

# %%
print(outliers)
# Out:
#                     sepal_length  sepal_width  petal_length  petal_width  \
# species
# Iris-virginica 117           7.7          3.8           6.7          2.2
#                119           6.0          2.2           5.0          1.5
#                131           7.9          3.8           6.4          2.0
#
#                            species
# species
# Iris-virginica 117  Iris-virginica
#                119  Iris-virginica
#                131  Iris-virginica

# %%
 # Q-8: What is the pairwise correlation of all features for each species?

# %%
correlations_by_species = Flower_Dataset.groupby('species').apply(lambda x: x.iloc[:, :-1].corr())
correlations_by_species
# Out:
# <ipython-input-16-dbb2cbe57e77>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   correlations_by_species = Flower_Dataset.groupby('species').apply(lambda x: x.iloc[:, :-1].corr())
#                               sepal_length  sepal_width  petal_length  \
# species
# Iris-setosa     sepal_length      1.000000     0.746780      0.263874
#                 sepal_width       0.746780     1.000000      0.176695
#                 petal_length      0.263874     0.176695      1.000000
#                 petal_width       0.279092     0.279973      0.306308
# Iris-versicolor sepal_length      1.000000     0.525911      0.754049
#                 sepal_width       0.525911     1.000000      0.560522
# ...

# %%
 # Q-9: Which species has the smallest variability in sepal length, and what is the standard deviation for each species?

# %%
sepal_length_std = Flower_Dataset.groupby('species')['sepal_length'].std()
least_variable_species = sepal_length_std.idxmin()
sepal_length_std, least_variable_species
# Out:
# (species
#  Iris-setosa        0.352490
#  Iris-versicolor    0.516171
#  Iris-virginica     0.635880
#  Name: sepal_length, dtype: float64,
#  'Iris-setosa')

# %%
 # Q-10: What percentage of samples for each species have petal length greater than 1.5 times their species' mean petal length?

# %%
def percentage_above_threshold(group):
    mean_petal_length = group['petal_length'].mean()
    threshold = 1.5 * mean_petal_length
    above_threshold = (group['petal_length'] > threshold).sum()
    return (above_threshold / len(group)) * 100

percentages = Flower_Dataset.groupby('species').apply(percentage_above_threshold)
# Out:
# <ipython-input-18-b89c0e4a55c6>:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   percentages = Flower_Dataset.groupby('species').apply(percentage_above_threshold)

# %%
print(percentages)
# Out:
# species
# Iris-setosa        0.0
# Iris-versicolor    0.0
# Iris-virginica     0.0
# dtype: float64
